# %% [markdown]
# <a href="https://colab.research.google.com/github/angelbastogz/masters-ai/blob/main/Introducci%C3%B3n%20a%20la%20IA/06_Visi%C3%B3n_computacional/Notebooks/13%20YOLO%20ultralytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este Colab está diseñado para introducirte al uso de la librería **Ultralytics YOLOv8**, que es una herramienta muy popular y eficiente para la **detección de objetos** (y otras tareas de visión por computadora) en imágenes y videos.

# %% [markdown]
# Tutorial original en ultralytics
#
# https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb#scrollTo=bpF9-vS_DAaf
#
#
# App para anotar/etiquetar imágenes de nuestra propia base de datos:
#
# https://app.roboflow.com/login

# %% [markdown]
# ### **Recursos (Celdas de Texto):**
#
# *   **`b1Ys4VeYJ97_`**: Esta celda de texto (`text_cell`) proporciona enlaces a recursos útiles:
#     *   El **tutorial original de Ultralytics** en Colab, que probablemente sea la fuente de gran parte de este notebook.
#     *   Una **aplicación (Roboflow)** para anotar y etiquetar imágenes. Esta es una herramienta crucial si necesitas crear tu propio dataset para entrenar modelos de detección de objetos, ya que los modelos de Machine Learning necesitan datos 'etiquetados' para aprender qué buscar.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.144 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.3/112.6 GB disk)

# %% [markdown]
# ### **Configuración Inicial (Celda de Código):**
#
# *   **`oUmyNE3tHt13`**: Esta celda de código (`code_cell`) realiza dos acciones importantes:
#     *   `%pip install ultralytics`: Instala la librería `ultralytics` en el entorno de Colab. `%pip` es un *comando mágico* de IPython que ejecuta `pip` dentro de la notebook.
#     *   `ultralytics.checks()`: Ejecuta una función de la librería para verificar que todo esté configurado correctamente y que los requisitos del sistema (como PyTorch y CUDA para la GPU) se cumplan. Esto asegura que YOLOv8 pueda funcionar eficientemente.

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLOv8 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %% [markdown]
# ### **1. Predicción (Celdas de Texto y Código):**
#
# Esta sección introduce cómo usar YOLOv8 para realizar predicciones o *inferencia* sobre nuevas imágenes.
#
# *   **`yhe8zrRYH6oz`**: Una celda de texto (`text_cell`) que explica que YOLOv8 se puede usar directamente desde la **interfaz de línea de comandos (CLI)** con el comando `yolo`. También menciona que se pueden pasar argumentos como `imgsz` (tamaño de la imagen) y que hay documentación disponible para más detalles.

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# Ultralytics 8.4.144 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 8.0ms
# Speed: 161.0ms preprocess, 8.0ms inference, 44.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# *   **`2q-INS4wH-VA`**: Esta celda de código (`code_cell`) demuestra la predicción:
#     *   `!yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'`: Este comando utiliza el modelo `yolov8n.pt` (una versión pequeña y rápida de YOLOv8) para detectar objetos en una imagen de 'zidane.jpg' directamente desde una URL. El `!` al inicio indica que es un comando de shell. El resultado muestra los objetos detectados (2 personas, 1 corbata) y guarda las imágenes con las detecciones en `/content/runs/detect/predict`.

# %% [markdown]
# ## 1. Detection
#
# YOLOv8 _detection_ models have no suffix and are the default YOLOv8 models, i.e. `yolov8n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %% [markdown]
# ### **1. Detección (Celdas de Texto y Código):**
#
# Esta sección se centra específicamente en los modelos de detección de objetos de YOLOv8.
#
# *   **`92P23YYFIIzH`**: Otra celda de texto (`text_cell`) que aclara que los modelos de detección de YOLOv8 no tienen sufijo (como `yolov8n.pt`) y que están preentrenados en el dataset COCO (un dataset muy grande y diverso de imágenes con objetos etiquetados).

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg', save=True)  # predict on an image
# Out:
# Ultralytics 8.4.144 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# *   **`g-ldJjbzIL-h`**: Esta es una celda de código (`code_cell`) más compleja que demuestra un flujo completo:
#     *   `from ultralytics import YOLO`: Importa la clase `YOLO` de la librería `ultralytics`.
#     *   `model = YOLO('yolov8n.pt')`: Carga el modelo `yolov8n.pt` preentrenado.
#     *   `model.train(data='coco128.yaml', epochs=3)`: ¡Aquí es donde se entrena el modelo! Aunque el `yolov8n.pt` ya está preentrenado, este comando lo **reentrena (fine-tunes)** sobre un dataset más pequeño llamado `coco128.yaml` por 3 épocas. El *output* de esta celda muestra el progreso del entrenamiento, métricas como mAP (mean Average Precision) y detalles sobre el dataset `coco128` que fue descargado y descomprimido.
#     *   `model('https://ultralytics.com/images/bus.jpg', save=True)`: Después de entrenar (o reentrenar), el modelo se usa para hacer una predicción en una nueva imagen (en este caso, una imagen de un autobús). `save=True` guarda los resultados de la predicción. El *output* final muestra los objetos detectados (personas, autobús, señal de stop) y dónde se guardaron los resultados.
