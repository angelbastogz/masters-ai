# %% [markdown]
# <a href="https://colab.research.google.com/github/angelbastogz/masters-ai/blob/main/Introducci%C3%B3n%20a%20la%20IA/Perceptr%C3%B3n%20multicapa/Notebooks/05%20Keras%20-%20multilayer%20perceptron%20-%20iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data
target = iris.target
Y = to_categorical(target).astype("uint8")
# 0 => [1 0 0]
# 1 => [0 1 0]
# 2 => [0 0 1]

# %%
idx = 0
print(X[idx])
print(target[idx])
print(Y[idx])
# Out:
# [5.1 3.5 1.4 0.2]
# 0
# [1 0 0]

# %%
model = keras.Sequential(
  [
    layers.Dense(3, activation="sigmoid", name="layer1", input_shape=(4,)),
    layers.Dense(3, activation="sigmoid", name="layer2"),
  ]
)

model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (None, 3)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (None, 3)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27 (108.00 B)
#  Trainable params: 27 (108.00 B)
# ...

# %%
y = model(X)
print(y[149])
# Out:
# tf.Tensor([0.4171195  0.53264564 0.3626347 ], shape=(3,), dtype=float32)

# %%
optimizer=tf.keras.optimizers.SGD(learning_rate=0.03)
loss=tf.keras.losses.MeanSquaredError()

model.compile(optimizer, loss)
history = model.fit(X, Y, epochs=500)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2422
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2409
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2396
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2385
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2374
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2365
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2356
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2348
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2341
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2335
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2329
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2324
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2319
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2314
# Epoch 15/500
# ...

# %%
plt.plot(history.history['loss'])
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %%
model.predict(np.array([[3,3,1,1]]))
